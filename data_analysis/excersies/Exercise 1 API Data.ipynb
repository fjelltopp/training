# %% [markdown]
# # Excersise 1: Api Data
#
# The aim of this excersice is to get data from the API and do some investigations and create some visualisations.
#
# It is also possible to create some of these visulisations in Excel and the demonstrators can help with that if you want to try it.
#
#
# The main goal of this excersies is to be able to choose a couple of clinics and compare the number of cases of a choosen disease per week. We want to create a plot that looks something like this:
#
#
#
#
#
# This Excersies consists of the following steps
# 1. Create a requests session and authenticated using username and password
# 2. Access data from the API and create a simple chart using matplotlib
# 3. Using location and code data to get API data for a specific disease / location
# 4. Creating a plot comparing cases from different locations
# 5. Creating a plot comparing different disease from the same location

# %%
import requests
from matplotlib import pylab
# %matplotlib notebook

# %%
# Create a session and authenticate it with server as described in the notes

# %% [markdown]
# To get weekly data from the API we can use the
# `/api/aggregate_year/<variable>/<location_id>` api endpoint. Let's start with getting the number of females. Females have the variable id **gen_1**.
#
# Then try to plot the values versus the weeks using pylab.plot().

# %%
# Get the aggreate data from the API

# %%
# Create the weekly plot

# %% [markdown]
# We have used location_id = 1 to get data from the whole country. Here is a list of ids and location name to help you find the location id based on the name of the location you want to investigate

# %%
location_data = session.get("https://jordan.emro.info/api/locations").json()
for l in location_data.keys():
    print("id:", l, "name:", location_data[l]["name"])
# Out:
# id: 1 name: Jordan
# id: 2 name: Ajloun
# id: 3 name: Amman
# id: 4 name: Aqaba
# id: 5 name: Balqa
# id: 6 name: Irbid
# id: 7 name: Jarash
# id: 8 name: Karak
# id: 9 name: Ma'an
# id: 10 name: Madaba
# id: 11 name: Mafraq
# id: 12 name: Petra
# id: 13 name: Ramtha
# id: 14 name: Tafeileh
# id: 15 name: Zarqa
# id: 16 name: Amman D
# id: 17 name: East Amman D
# id: 18 name: Balqa D
# id: 19 name: South Shouneh D
# id: 20 name: Deir Alla D
# id: 21 name: Irbid D
# id: 22 name: Bani Kenana D
# id: 23 name: Koura D
# id: 24 name: Ramtha D
# id: 25 name: North Aghwar D
# id: 26 name: Mafraq D
# id: 27 name: North Badia D
# id: 28 name: Rweished D
# id: 29 name: Berm
# id: 30 name: Karak D
# id: 31 name: South Ghour D
# id: 32 name: Zarqa D
# id: 33 name: Tafeileh D
# id: 34 name: Ma'an D
# id: 35 name: Jarash D
# id: 36 name: Ajloun D
# id: 37 name: Aqaba D
# id: 38 name: Madaba D
# id: 39 name: Petra D
# id: 40 name: Mafraq Foreigner Clinic
# id: 41 name: Al-Dleil
# id: 42 name: Wadi Al-Hajar
# id: 43 name: Hai Al-Rasheed
# id: 44 name: Bereen
# id: 45 name: Jabal Al-Amir Faisal
# id: 46 name: Shbeeb
# id: 47 name: Hai Al-Ameer Abdullah
# id: 48 name: Jabal Tareq
# id: 49 name: Hai Al-Ameer Mohammad
# id: 50 name: Isskan Al-Amir Talal
# id: 51 name: Al-Hashimieh
# id: 52 name: Al-Sukhna
# id: 53 name: Abu-Al-Zeighan
# id: 54 name: Al-Zawahreh
# id: 55 name: with Dr. Sami
# id: 56 name: Al-Rousifeh Al-Shamali
# id: 57 name: Al-Khalidiah
# id: 58 name: Bal'ama
# id: 59 name: Al-Mansourah
# id: 60 name: Al-Mafraq Al-Shamel
# id: 61 name: Sama Al-Sarhaan
# id: 62 name: Rihab
# id: 63 name: Al-Za'tari
# id: 64 name: Khaled Bin Al-Walid
# id: 65 name: Al-Ba'ej
# id: 66 name: Gynecoloy & Obstetrics and Children Hospital
# id: 67 name: Al-Badiah Al-Shamali
# id: 68 name: Um Al-Qutein
# id: 69 name: Deir Al-kahf
# id: 70 name: Al-Safawi
# id: 71 name: Um Al-Jmal
# id: 72 name: Al-Ramtha Al-Gharbi
# id: 73 name: Al-Turra Al-Janoubi
# id: 74 name: Al-Sareeh
# id: 75 name: Kufur Youba
# id: 76 name: Dahiyat Al-Hussein
# id: 77 name: Deir Abi Se'eid
# id: 78 name: Al-Ramtha Al-Shamel
# id: 79 name: Bait Ra'ass
# id: 80 name: Malka
# id: 81 name: Kraimeh
# id: 82 name: Rahmah Hospital
# id: 83 name: Al-Razi
# id: 84 name: Al-Shajrah Al-Shamali
# id: 85 name: Al-Tatweer Al-Hadari
# id: 86 name: Al-Na'imeh
# id: 87 name: Samou'e
# id: 88 name: Al-Turra Al-Shamali
# id: 89 name: Al-Ramtha Main
# id: 90 name: Al-Zarka Al-Jadidah
# id: 91 name: Al-Qatranah
# id: 92 name: Karak Focal
# id: 93 name: Abu Banna
# id: 94 name: Um-Alamad
# id: 95 name: Al-Nuzha
# id: 96 name: Al Mwagar 1
# id: 97 name: Al-Amira Basma
# id: 98 name: Marka Al-Shamel
# id: 99 name: Al-Hashimi Al-Shamali
# id: 100 name: Kufor Awan
# id: 101 name: Yarmouk Hospital
# id: 102 name: Sahel Houran
# id: 103 name: Al-Husseiniya
# id: 104 name: Soumow Al-Amira Rahma Bent Al-Hasan
# id: 105 name: Ma'an focal
# id: 106 name: Al-Jafer
# id: 107 name: Al-Shobak
# id: 108 name: Al-Eiss
# id: 109 name: Al-Hassa
# id: 110 name: Al-Jarf
# id: 111 name: Wadi Al-Rayyan
# id: 112 name: Samar
# id: 113 name: Hriema
# id: 114 name: Hakma
# id: 115 name: Sama Al-Rousan
# id: 116 name: Abu-Nsseir
# id: 117 name: Ain Al-Basha
# id: 118 name: National Addiction Center
# id: 119 name: Al Hussein Hospital
# id: 120 name: Al-Hadadah
# id: 121 name: Al-Jazazah
# id: 122 name: Al-Kfeir
# id: 123 name: Al-Mastaba
# id: 124 name: Al-Reesha
# id: 125 name: Lost
# id: 126 name: Private
# id: 127 name: Training device - with Dr. Refqi
# id: 128 name: IT Central Focal
# id: 129 name: Dr. Sultan Qasrawi
# id: 130 name: Dr. Bassam Shadfan
# id: 131 name: Um-Alrassas
# id: 132 name: Nuzhat Sahab
# id: 133 name: Sallehiat Al-Abed
# id: 134 name: Al-Jweideh
# id: 135 name: Daba'a
# id: 136 name: Rajm Al-Shami
# id: 137 name: Al-Nathif
# id: 138 name: Qasr Al-adel
# id: 139 name: CD directorate
# id: 140 name: Al-Rmail
# id: 141 name: Husban
# id: 142 name: Al-Muraqab
# id: 143 name: Ereinbeh Al-Gaharbiah
# id: 144 name: Abu Sous
#
# id: 145 name: Al-Thahabiah Al-Sharqiah
# id: 146 name: Al-Rama
# id: 147 name: Al-Qoussour (Al-Hashimi Al-Janoubi)
# id: 148 name: Zbood
# id: 149 name: Al-Bassa
# id: 150 name: Dr. Nabil Sabri
# id: 151 name: Um Al-Qutain
# id: 152 name: Marka airport
# id: 153 name: Al-Rawdah
# id: 154 name: Al-Zouhour
# id: 155 name: Tabarbour (Tareq)
# id: 156 name: Al-Adassieh
# id: 157 name: Abu Ayoub Al-Ansary (Al-Hilal)
# id: 158 name: Al -Istiqlal
# id: 159 name: Al-Rabwah (Hamlan)
# id: 160 name: Um Hussein
# id: 161 name: Al-Hashimieh
# id: 162 name: SakanKareem-Abu Alanda
# id: 163 name: Jabal Amman
# id: 164 name: Al-Nasser
# id: 165 name: Abu Syah
# id: 166 name: Safout
# id: 167 name: Al Shouneh Hospital
# id: 168 name: Al-Balawneh
# id: 169 name: Al-Bqei'e
# id: 170 name: Al-Fuheiss
# id: 171 name: Al-Jawasreh
# id: 172 name: Al-Jofah
# id: 173 name: Al-Karamah
# id: 174 name: Dr. Khalil Kenani
# id: 175 name: Al-Karamah Hospital
# id: 176 name: Al-Khandag wa Al-Iskan
# id: 177 name: Al-Manshieh
# id: 178 name: Al-Msharfeh
# id: 179 name: Al-Nahda (Al-Hajar Al-Twall)
# id: 180 name: Al-Rawdah
# id: 181 name: Al-Rumman
# id: 182 name: Al-Rweihah
# id: 183 name: Al-Salalem
# id: 184 name: Al-Salalem Al-Oulwi
# id: 185 name: Al-Salt
# id: 186 name: Al-Sarou
# id: 187 name: Al-Sbeihi
# id: 188 name: Al-Shounah Al-Janoubiah
# id: 189 name: Al-Sleihi
# id: 190 name: Aqaba Foreigner Clinic
# id: 191 name: Tafeileh Foreigner Clinic
# id: 192 name: Balqa Foreigner Clinic
# id: 193 name: Madaba Foreigner Clinic
# id: 194 name: Kom Al-Raf
# id: 195 name: Jarash Foreigner Clinic
# id: 196 name:
# id: 197 name: Abdel Ra'of IT focal
# id: 198 name: Ahmad IT focal
# id: 199 name: Al-Ramtha Al-Shamali
# id: 200 name: Al-shajrah Al-Janoubi
# id: 201 name: Prince Hamza Hospital
# id: 202 name: Khasha' Al-Sleiteen
# id: 203 name: unrwa
# id: 204 name: North Badia Hospital
#
# id: 205 name: Al Nadeem Governmental Hospital
# id: 206 name: Al-Thira'a (Hai Nazzal)
# id: 207 name: Jabal Al-Jofeh
# id: 208 name: Al-Bweidah
# id: 209 name: Amrawa
# id: 210 name: Sahab Foreigner Clinic
# id: 211 name: Ajloun Foreigner Clinic
# id: 212 name: Central Foreigner Clinic
# id: 213 name: Abu Nsseir Foreigner Clinic
# id: 214 name: Al-Nasser Foreigner Clinic
# id: 215 name: Alweibdeh Foreigner Clinic
# id: 216 name: Sweileh Foreigner Clinic
# id: 217 name: Masah AlNoor
# id: 218 name: Ramtha Focal
# id: 219 name: Irbid Foreigner Clinic
# id: 220 name: Zarqa Foreigner Clinic
# id: 221 name: Ma'an Foreigner Clinic
# id: 222 name: Karak Foreigner Clinic
# id: 223 name: Ramtha Public Hospital
# id: 224 name: Al-Mkeifteh
# id: 225 name: Hai Al-Hussein
# id: 226 name: Al-Rweished Hospital
# id: 227 name: Al-Twall Al-Janoubi
# id: 228 name: Al-Twall Al-Shamali
# id: 229 name: Al-Yazidieh
# id: 230 name: Allan
# id: 231 name: Armeimeen
# id: 232 name: Balqa Focal
# id: 233 name: Baqan
# id: 234 name: Bayouda Al-Sharqieh
# id: 235 name: Istishariah Clinic
# id: 236 name: Deir Alla
# id: 237 name: Abdar
# id: 238 name: Princess Basma Hospital
# id: 239 name: Al-Mkheibeah Al-Tahta
# id: 240 name: Abi Obidah Hospital
# id: 241 name: Amman Al-Shamel
# id: 242 name: Khreibat Al-Souq
# id: 243 name: Amman Focal
# id: 244 name: Al-Awdah (Um-Tineh)
# id: 245 name: Al-Basheer Hospital
# id: 246 name: Ein Jana
# id: 247 name: Ajloun
# id: 248 name: Safa Al-Jadeed (Al-Jabal Al-Akhdar)
# id: 249 name: Abeen
# id: 250 name: Rajeb
# id: 251 name: Sakhra
# id: 252 name: Awsarah
# id: 253 name: Ein Albostan
# id: 254 name: Ajloun Focal
# id: 255 name: Deir Alla Focal
# id: 256 name: Dirar Ibn Al-Azwar
# id: 257 name: Eira
# id: 258 name: Fuhais Hospital
# id: 259 name: Al-Mansourah
# id: 260 name: Al-Qadissiah
# id: 261 name: Eskan Abu-Nsseir
# id: 262 name: Wadi El-Seer
# id: 263 name: Zarqa Governmental Hospital
# id: 264 name: Prince Hamza Quarter
# id: 265 name: Prince Faisal Hospital
# id: 266 name: Al-Azraq
# id: 267 name: Al-Khazzan
# id: 268 name: Al-Shameya
# id: 269 name: Al-Qweirah
# id: 270 name: Al-Amera Basma
# id: 271 name: Aqaba focal
# id: 272 name: Abu Seedo
# id: 273 name: Hibrass
# id: 274 name: Al-Manshiah
# id: 275 name: Mua’ath Ben Jabal Hospital
# id: 276 name: Queen Rania Hospital
# id: 277 name: Ma'an Hospital
# id: 278 name: Roudet Al-Amir Al-Rasheed
# id: 279 name: Madaba Focal
# id: 280 name: East Amman focal
# id: 281 name: Jamil Totanji Hospital
# id: 282 name: Al-Jeeza
# id: 283 name: Princess Salma Hospital
# id: 284 name: Al-Weibdeh Al-Sharqi
# id: 285 name: Awajan
# id: 286 name: Al-Msheirfeh Al-Shamel
# id: 287 name: Hartha
# id: 288 name: Yabla
# id: 289 name: Koufor Soum
# id: 290 name: Isskan Al-Hashimieh
# id: 291 name: Marj Al-Hamam
# id: 292 name: Mafraq Focal
# id: 293 name: Al-Beshrieh
# id: 294 name: Al-Ashrafiah
# id: 295 name: Um Al-Jmal
# id: 296 name: Talal
# id: 297 name: Ghoor Al-Safi Hospital
# id: 298 name: Al-Karak
# id: 299 name: Al Iman Al Hokomi Hospital
# id: 300 name: Al-Amir Hasan (Kufranjah)
# id: 301 name: Anjara
# id: 302 name: Eshtafina
# id: 303 name: Al-Ameer Hashem
# id: 304 name: Amman Directorate stock
# id: 305 name: Al-Karak Governmental Hospital
# id: 306 name: Al-Marrekh
# id: 307 name: Hai Al-Karamah
# id: 308 name: Al-Deesah
# id: 309 name: Qreiqrah
# id: 310 name: Rahma
# id: 311 name: Iskan Al-Maghareeb wa Um-Al-Zaytoon
# id: 312 name: Khazma
# id: 313 name: Ma'adi
# id: 314 name: Al-Tafilah Al-Awali
# id: 315 name: Al-Tafilah Al-Shamel
# id: 316 name: Princess Salha(Ghor Al-Safi)
# id: 317 name: Al-Ma'amourah
# id: 318 name: Ay
# id: 319 name: Al-Mazar Al-Janoubi
# id: 320 name: Ma'an
# id: 321 name: Mahess
# id: 322 name: Al-Msheirfeh
# id: 323 name: Al-Qadissiah
# id: 324 name: Al-Rashadiah
# id: 325 name: Al-Razi
# id: 326 name: Al-Taibeh
# id: 327 name: Jamia'at Al-Yarmouk
# id: 328 name: Raya Hospital
# id: 329 name: Tharghrat Al-Jib
# id: 330 name: Al-Dejnieh
# id: 331 name: Al-Rafa'yat
# id: 332 name: Sabha
# id: 333 name: Rasoun
# id: 334 name: Al-Wahadneh
# id: 335 name: San'ar
# id: 336 name: Al-Hashimiah
# id: 337 name: Nadrah
# id: 338 name: Al-Harsh
# id: 339 name: Al-Mazrah
# id: 340 name: Fa'a
# id: 341 name: Hosha
# id: 342 name: Sahem
# id: 343 name: Hatem
# id: 344 name: Al-Mansourah
# id: 345 name: Al-Ma'abar Wadi Alordon
# id: 346 name: Al-Sheikh Hussein
# id: 347 name: Ein Bani Hasan
# id: 348 name: Amra wa Ameira
# id: 349 name: Sahab
# id: 350 name: Al-Qweismeh
# id: 351 name: Kharja
# id: 352 name: Al-Taibeh Al-Janoubieh
# id: 353 name: Petra (Wadi Mousa)
# id: 354 name: Sweileh
# id: 355 name: Na'our
# id: 356 name: Hayyan Rweibed
# id: 357 name: Mafraq Hospital
# id: 358 name: Um Al-Sarb
# id: 359 name: Al-Mabroukah
# id: 360 name: Bani Kenana Focal
# id: 361 name: with Dr. Sami/fateen
# id: 362 name: Ghor Al-Mazra'a
# id: 363 name: Al-Rabba
# id: 364 name: Ghor Al-Haditha
# id: 365 name: Fouqou'e
# id: 366 name: Al-Dafyaneh
# id: 367 name: Al-Hai Al-Janoubi
# id: 368 name: Balila
# id: 369 name: Barma
# id: 370 name: Deir Al-Liyat
# id: 371 name: Jabbah
# id: 372 name: Aqraba
# id: 373 name: Irbid Focal
# id: 374 name: Badee’ah Hospital
# id: 375 name: Waqass
# id: 376 name: Lub
# id: 377 name: Theeban Al-Shamel
# id: 378 name: Madaba Al-Sharqy
# id: 379 name: Al-Mreigha
# id: 380 name: Missing
# id: 381 name: Al-Istiqlal
# id: 382 name: Al-Areed
# id: 383 name: Shamal Madaba
# id: 384 name: Karak Directorate Stock
# id: 385 name: South Ghour Focal
# id: 386 name: Al-Thuneibeh
# id: 387 name: Al-Mashare'e
# id: 388 name: Arhab
# id: 389 name: Halawa
# id: 390 name: Ba'aoun
# id: 391 name: Arajan
# id: 392 name: Al-Muagar
# id: 393 name: Natel
# id: 394 name: Rawdat Al-Amira Basma
# id: 395 name: Um Al-Nia'am  Al awali
# id: 396 name: Al-Kom Al-Ahmar
# id: 397 name: Al-Za'tari Alshamel
# id: 398 name: Al-Baldah Al-Qadeemah
# id: 399 name: Al-Aqaba
# id: 400 name: Rum
# id: 401 name: King Abdullah Moa'asses
# id: 402 name: Al-Areesh
# id: 403 name: Madaba Al-Gharby
# id: 404 name: Dalilah Al-Hamaideh
# id: 405 name: Mukhayam Madaba
# id: 406 name: Maleeh
# id: 407 name: Al-Shounah Al-Shamalieh
# id: 408 name: Um-Qais
# id: 409 name: Al Ameriah
# id: 410 name: Zarqa Focal
# id: 411 name: Jarash
# id: 412 name: Jarash Focal
# id: 413 name: Jarash Hospital
# id: 414 name: Jaber Al-Sarhaan
# id: 415 name: Al-Hamra'a
# id: 416 name: Manshiat Bani Hasan
# id: 417 name: Aydoun Bani Hasan
# id: 418 name: Al-Mafraq
# id: 419 name: Um Lolo Correctional Facility
# id: 420 name: Mothalath Al-Arda
# id: 421 name: Moubess
# id: 422 name: Prince Hussein Hospital
# id: 423 name: North Badia Focal
# id: 424 name: Al-Zbeidiah
# id: 425 name: Al-Rafeed
# id: 426 name: Al-Farouq
# id: 427 name: Arweem
# id: 428 name: Ayma
# id: 429 name: Central Laboratory
# id: 430 name: Mghayar Al-Sarhaan
# id: 431 name: Dr. Sami Sheikh Ali
# id: 432 name: Irbid correctional facility
# id: 433 name: Al-Hemmeh Al-Ordounieh
# id: 434 name: Karak Directorate Stock
# id: 435 name: Ar-Rukban
# id: 436 name: Al-Hadalat
# id: 437 name: Ruwayshid Camp
# id: 438 name: Kufur Khal
# id: 439 name: Mreisse'e
# id: 440 name: Nahla
# id: 441 name: Qafqafa
# id: 442 name: Sakeb
# id: 443 name: Souf
# id: 444 name: Ma'een
# id: 445 name: Haneena
# id: 446 name: Princess Iman Hospital
# id: 447 name: Riyadi
# id: 448 name: Balqa directorate stock
# id: 449 name: S.Shouneh Focal
# id: 450 name: Salhoub
# id: 451 name: Marou
# id: 452 name: Al-Mgheier
# id: 453 name: Jfein
# id: 454 name: Arhaba
# id: 455 name: Zahar
# id: 456 name: Douqara
# id: 457 name: Al-Hilalia
# id: 458 name: Al-Faisalieh
# id: 459 name: Al-Faiha'a
# id: 460 name: Madaba Al-Janoubi
# id: 461 name: Deir Yousef
# id: 462 name: Jahfeieh
# id: 463 name: Beit Yafa
# id: 464 name: Kufur Rakeb
# id: 465 name: Qameem
# id: 466 name: Al-Husson
# id: 467 name: Ibn Seena
# id: 468 name: Kufur Assad
# id: 469 name: Hofa
# id: 470 name: Janein Al-Safa
# id: 471 name: Al-Turkman
# id: 472 name: Tabnah
# id: 473 name: Kufor Eibel
# id: 474 name: Prince Asem
# id: 475 name: Tal Almantah
# id: 476 name: Thahrat Al-Ramlah
# id: 477 name: Um-Jozah
# id: 478 name: Wadi Al-Akrad
# id: 479 name: Wadi El-Hoor
# id: 480 name: Jreineh
# id: 481 name: Al-Azayda
# id: 482 name: Sal
# id: 483 name: Jdeita
# id: 484 name: Houarah
# id: 485 name: Ela'al
# id: 486 name: Beit Eidess
# id: 487 name: Zoubia
# id: 488 name: Zamal
# id: 489 name: Kufur Jayez
# id: 490 name: Al-Barha
# id: 491 name: Deir Al-Sa'anah
# id: 492 name: Al-Kharaj
# id: 493 name: Al-Mazar
# id: 494 name: Samma
# id: 495 name: Habka
# id: 496 name: Al-Ashrafiah
# id: 497 name: Hour
# id: 498 name: Soum
# id: 499 name: Jijeen
# id: 500 name: Bushra
# id: 501 name: Kufur Al-Ma'a
# id: 502 name: Aydoun
# id: 503 name: Eman Amman IT focal
# id: 504 name: Katm
# id: 505 name: Anbah
# id: 506 name: Samad wa Al-Za'tarah
# id: 507 name: Fo'ara
# id: 508 name: Al-Zahrawi
# id: 509 name: Al-Twaal
# id: 510 name: Al-Thahabiah Al-Gharbiah
# id: 511 name: Al-Tatweer Al-Hadari(Marka)
# id: 512 name: Al-Naqirah
# id: 513 name: Al-Taj
# id: 514 name: Um-Qasseer / Al-Maqablein
# id: 515 name: Um-Albasateen
# id: 516 name: Al-Manarah
# id: 517 name: Aqaba Directorate stock
# id: 518 name: Bassirah
# id: 519 name: Ein Al-Baidah
# id: 520 name: Ghrandal
# id: 521 name: Jaber AlAnsari
#
# id: 522 name: NoorDein IT Tafeileh
#
# id: 523 name: Sanfahah
# id: 524 name: Tafeileh Correctional Facility
# id: 525 name: Al-Mqar'eieh
# id: 526 name: Ma'an Al-Garbi
# id: 527 name: Eil
# id: 528 name: Al-Isteklal
# id: 529 name: Al-Sharah
# id: 530 name: Muthalath Al-Shobak
# id: 531 name: Al-Madawara
# id: 532 name: Al-Farthakh
# id: 533 name: Athruh
# id: 534 name: Al-Abdaliah
# id: 535 name: Dalagha
# id: 536 name: Manshiat Abu Hammour
# id: 537 name: Adar
# id: 538 name: Al-Rajef
# id: 539 name: Al-Marj
# id: 540 name: Karak Directorate stock
# id: 541 name: Mrawed
# id: 542 name: Al-Jadidah
# id: 543 name: Damnah
# id: 544 name: Rakeen
# id: 545 name: Al-Iraq
# id: 546 name: Al-Qsser
# id: 547 name: Joza
# id: 548 name: Al-Yarout
# id: 549 name: Mu'aab
# id: 550 name: That Ra'ass
# id: 551 name: Kuthraba
# id: 552 name: Mou'ta
# id: 553 name: Al-Adnaniah
# id: 554 name: Sarfa
# id: 555 name: Majra
# id: 556 name: Muhee'
# id: 557 name: Al-Ghweir
# id: 558 name: Emre'e
# id: 559 name: Al-Samakiah
# id: 560 name: Wadi Al-Karak
# id: 561 name: Soul
# id: 562 name: Al-Thnayah
# id: 563 name: Al-Jada'a
# id: 564 name: Al-Hewaya
# id: 565 name: Al-Shahaibeh
# id: 566 name: Bteir
# id: 567 name: Dr. Refqi Mahmoud
# id: 568 name: Don't know with who ??
# id: 569 name: Al-Kamsha
# id: 570 name: Al-Alouk
# id: 571 name: Al-Oumari
# id: 572 name: Um Rommana
# id: 573 name: Khadem AlHarameen
#
# id: 574 name: Al-Tatweer Al-Hadari(Yajouz)
# id: 575 name: Al-Batrawi (Hai Ma'asoum)
# id: 576 name: Hai Al Jundi
# id: 577 name: Al-Naqab
# id: 578 name: Isskan Al-Amir Hashem
# id: 579 name: Hai Al-Falah
# id: 580 name: Al-Hallabat Al-Sharqy
# id: 581 name: Ra'ss Munif
# id: 582 name: Jreeba
# id: 583 name: Um-Al-Sleih
# id: 584 name: Srout
# id: 585 name: Al-Alia
# id: 586 name: Al-Laban
# id: 587 name: Al-Jmaiel
# id: 588 name: Khashafiat Al-Dabaybeh
# id: 589 name: Al-Zmeileh
# id: 590 name: Matar Al-Malika Alia
# id: 591 name: Al-Mustanada
# id: 592 name: Abu-Alanda
# id: 593 name: Al-Taibeh
# id: 594 name: Um- Nouwara
# id: 595 name: Ohod
#
# id: 596 name: Shafa Badran
# id: 597 name: Bader
# id: 598 name: Dahiyat Al-Hussein
# id: 599 name: Al-A'al
# id: 600 name: Abu Hulailifah
# id: 601 name: Al-Yadoda
# id: 602 name: Asem IT Focal
# id: 603 name: Yarqa
# id: 604 name: Wafa' IT focal
# id: 605 name: Dr. Fateen
# id: 606 name: Tafeileh Focal
# id: 607 name: Wad Zaid
# id: 608 name: Zay
# id: 609 name: North Aghwar focal
# id: 610 name: Ahlam IT focal Jarash
# id: 611 name: Areej Petra IT focal
# id: 612 name: Wafa'a IT Zarqa
# id: 613 name: Islamic Hospital
# id: 614 name: Jordan University Hospital
# id: 615 name: Jordan Hospital
# id: 616 name: Specialty Hospital
# id: 617 name: Istiklal Hospital
# id: 618 name: Al-Essra Hospital
# id: 619 name: Jordan Red Crescent Hospital
# id: 620 name: Italian Hospital
# id: 621 name: Al Khalidi Medical Center
# id: 622 name: Arab Medical Center
# id: 623 name: Istishari Hospital
# id: 624 name: Luzmila Hospital
# id: 625 name: Shmaisani Hospital
# id: 626 name: Ibn Al Haytham Hospital
# id: 627 name: Modern Wisdom Hospital
# id: 628 name: Jabal Al Zaitoon Hospital
# id: 629 name: Qasr Shabeeb Hospital
# id: 630 name: Razi Jadeed Hospital
# id: 631 name: Al-Mahabbeh Hospital
# id: 632 name: Ibn Al Nafis Hospital
# id: 633 name: Irbid Specialized Hospital
# id: 634 name: King Abdullah University Hospital
# id: 635 name: Italian Hospital
# id: 636 name: Islamic Hospital

# %% [markdown]
# Here follows also a selection of codes you can use for this excersice

# %%
variables = {}
for category in ["gender", "age", "cd_tab", "ncd_tab"]:
    data = session.get("https://jordan.emro.info/api/variables/" + category).json()
    for l in data.keys():
        print("Variable id:", l, "name:", data[l]["name"])
    variables.update(data)
# Out:
# Variable id: gen_1 name: Male
# Variable id: gen_2 name: Female
# Variable id: age_1 name: <5
# Variable id: age_2 name: 5-9
# Variable id: age_3 name: 10-14
# Variable id: age_4 name: 15-19
# Variable id: age_5 name: 20-59
# Variable id: age_6 name: >60
# Variable id: cmd_1 name: Cholera
# Variable id: cmd_10 name: Tetanus
# Variable id: cmd_11 name: Diphtheria
# Variable id: cmd_12 name: Whooping cough
# Variable id: cmd_13 name: Scarlet fever
# Variable id: cmd_14 name: Meningitis
# Variable id: cmd_15 name: Syphilis
# Variable id: cmd_16 name: Gonorrhoea
# Variable id: cmd_17 name: Relapsing fevers
# Variable id: cmd_18 name: Typhus fever
# Variable id: cmd_19 name: Polio
# Variable id: cmd_2 name: Typhoid fever
# Variable id: cmd_20 name: Rabies
# Variable id: cmd_21 name: Viral meningitis
# Variable id: cmd_22 name: Dengue Fever
# Variable id: cmd_23 name: Yellow fever
# Variable id: cmd_24 name: Viral haemorrhagic fever
# Variable id: cmd_25 name: Ebola virus disease
# Variable id: cmd_26 name: Chicken pox
# Variable id: cmd_27 name: Measles
# Variable id: cmd_28 name: Rubella
# Variable id: cmd_29 name: Hepatitis A
# Variable id: cmd_3 name: Bloody diarrhoea
# Variable id: cmd_30 name: Hepatitis B
# Variable id: cmd_31 name: Hepatitis C
# Variable id: cmd_32 name: Hepatitis E
# Variable id: cmd_33 name: Hepatitis (Unspecificed)
# Variable id: cmd_34 name: HIV
# Variable id: cmd_35 name: Mumps
# Variable id: cmd_36 name: Ringworm
# Variable id: cmd_37 name: Malaria
# Variable id: cmd_38 name: Leishmaniasis
# Variable id: cmd_39 name: Schistosomiasis
# Variable id: cmd_4 name: Food Poisoning
# Variable id: cmd_40 name: Scabies
# Variable id: cmd_41 name: Influenza-like illness
# Variable id: cmd_42 name: Bacterial meningitis
# Variable id: cmd_43 name: Haemophilus meningitis
# Variable id: cmd_44 name: Non-meningicoccal meningitis
# Variable id: cmd_45 name: Animal Bite
# Variable id: cmd_46 name: Diarrhoea
# Variable id: cmd_47 name: Severe Acute Respiratory Illness
# Variable id: cmd_48 name: Acute Flaccid Paralysis
# Variable id: cmd_5 name: Tuberculosis
# Variable id: cmd_6 name: Plague
# Variable id: cmd_7 name: Anthrax
# Variable id: cmd_8 name: Brucellosis
# Variable id: cmd_9 name: Leprosy
# Variable id: ncd_1 name: Diabetes mellitus
# Variable id: ncd_2 name: Hypertension
# Variable id: ncd_3 name: Chronic Obstructive Pulmonary Disease (COPD)
# Variable id: ncd_4 name: Asthma
# Variable id: ncd_6 name: Other NCD

# %% [markdown]
# ## Creating a plot of weekly case numbers comparing different locations
#
# Let us now try to create a plot of cases with your chosen disease and for your chosen clinics. First get a plot of cases per week for one clinic. Then try to add a line from another clinic. A nice solution for this is to write a loop over a list of clinic ids and then add a line to the plot for each id.

# %%
# Create a plot comparing a disease for a few different clinics

# %% [markdown]
# ## Creating a plot to compare disease from the same clinic

# %%
# Create a plot comparing two different diseases from the same clinic

# %% [markdown]
# # Extra excersises
#
# A lot of improvements can be done to format these plots to make them look better. It is also possible to change them into bar charts etc.
