# %% [markdown]
# # Exercise 2: Analysing log data
#
# The aim of this excersies is to analyse data from the user logs generated by the Meerkat system.
#
# Every time a page is loaded or the api is called, the actions are logged in a database. The data gathered looks like this:
#
# Metadata:
#
# `
# timestamp - time of event, defined at the client as the logging request is sent
# type - Type of event:
# 	User-activity - user prompted activity in front end
# 	Batch-job - scheduled batch job
# 	Admin - administrative activity
# source - deployment ID
# source_type - frontend/api/abacus/auth etc: Module that is performing the logging
# implementation - country or organization name
# Event Data (JSON):
#     User-activity:
#         {
#             “path": <relative path>,
#             "role": <user roles>,
#             "user": <user account>,
#             "base_url": <accessed url>,
#             "full_url": <full accessed url>,
#             "request_time": <time spent to deliver request response>
#          }
# `
#
# The main questions we want to explore are the following:
#
# * Who are the most active users
# * What pages are they visiting
# * Look at the request time. Which urls take the most time, is there large variability in the request time
# * What time of day are people accessing the site
#
#
# This data can be explored in two ways. The first following this tutorial is using the python pandas package. The second is to explore this data using SQL. Ask a demonstrator to help you get started with an SQL session to access this data.
#
# This notebook contains some help to get the log data into pandas then you can explore the data on your own to aser the questions above. If you want some ideas of the capabilities of pandas you can look at this resource: https://pandas.pydata.org/pandas-docs/stable/10min.html

# %%
import pandas as pd
import sqlalchemy
# %matplotlib notebook
engine = sqlalchemy.create_engine("postgresql+psycopg2://postgres:postgres@localhost/event_db")
data = pd.read_sql_query("SELECT * from log", engine)
data = pd.concat([data, data["event_data"].apply(pd.Series)], axis=1)

# %%
# Examples

data["user"].value_counts()
# Out:
# cd-clinic         1126
# ncd-clinic         585
# rania              370
# cd-dir             207
# refqi              132
# gunnar             107
# jberry              81
# admin               46
# sami                28
# report-emails       20
# jsoppela            12
# reports-jor-cd       2
# Name: user, dtype: int64

# %%
data["base_url"].value_counts()
# Out:
# http://jordan.emro.info/en/                                                                                            714
# http://jordan.emro.info/                                                                                               710
# http://jordan.emro.info/en                                                                                             704
# http://jordan.emro.info/api/key_indicators                                                                             702
# http://iers.moh.gov.jo/api/locations                                                                                   361
# http://iers.moh.gov.jo/en/login                                                                                        253
# http://iers.moh.gov.jo/api/locationtree                                                                                233
# http://iers.moh.gov.jo/api/variables/pc                                                                                168
# http://iers.moh.gov.jo/api/variables/Chapter                                                                           166
# http://iers.moh.gov.jo/api/variables/visit                                                                             165
# http://iers.moh.gov.jo/api/epi_week                                                                                    149
# http://iers.moh.gov.jo/api/completeness/reg_10/1/6/1/4,5                                                                92
# http://iers.moh.gov.jo/en/login_request                                                                                 92
# http://iers.moh.gov.jo/api/variables/gender                                                                             92
# http://iers.moh.gov.jo/api/variables/nationality                                                                        91
# http://iers.moh.gov.jo/api/variables/status                                                                             91
# http://iers.moh.gov.jo/api/variables/age                                                                                81
# http://iers.moh.gov.jo/en/technical/                                                                                    64
# http://iers.moh.gov.jo/api/completeness/reg_11/1/6/1/4,5                                                                56
# http://iers.moh.gov.jo/en/                                                                                              56
# http://iers.moh.gov.jo/api/tot_map                                                                                      51
# http://iers.moh.gov.jo/api/aggregate_alerts/1/2017-05-01T00:00:00                                                       45
# http://iers.moh.gov.jo/api/variables/alert                                                                              45
# http://iers.moh.gov.jo/api/alerts                                                                                       45
# http://iers.moh.gov.jo/api/aggregate_category/Chapter/32/2017/tot_1                                                     44
# http://iers.moh.gov.jo/favicon.ico/                                                                                     44
# http://iers.moh.gov.jo/api/aggregate_category/pc/32/2017/tot_1                                                          44
# http://iers.moh.gov.jo/api/aggregate_category/visit/32/2017                                                             44
# http://iers.moh.gov.jo/api/non_reporting/reg_10/1/0/mental                                                              43
# http://iers.moh.gov.jo/api/aggregate_category/gender/1/2017/prc_1                                                       40
#                                                                                                                       ...
# http://iers.moh.gov.jo/api/aggregate_category/Chapter/519/2017/tot_1                                                     1
# http://jordan.emro.info/wp-login.php                                                                                     1
# http://jordan.emro.info/api/aggregate_category/nationality/16/2017/prc_2                                                 1
# http://jordan.emro.info/cms/wp-includes/wlwmanifest.xml                                                                  1
# http://iers.moh.gov.jo/en/technical/ncd-completeness/loc_33                                                              1
# http://iers.moh.gov.jo/en/technical/ncd-completeness                                                                     1
# http://iers.moh.gov.jo/api/aggregate_category/pc/90/2017/tot_1                                                           1
# http://iers.moh.gov.jo/api/aggregate_category/Chapter/582/2017/tot_1                                                     1
# http://10.0.1.86/reports/email/pip/1/                                                                                    1
# http://iers.moh.gov.jo/en/reports/pip/1/2017-09-17T00:00:00.000Z/2016-09-01T01:00:00.000Z                                1
# http://dev.jordan.aws.emro.info/api/locationtree                                                                         1
# http://demo.aws.emro.info/api/aggregate_category/nationality/1/2017/tot_1                                                1
# http://iers.moh.gov.jo/api/aggregate_category/Chapter/580/2017/tot_1                                                     1
# http://iers.moh.gov.jo/api/reports/cd_public_health/443/2017-08-31T00:00:00.000Z/2017-08-01T00:00:00.000Z                1
# http://iers.moh.gov.jo/en/technical/presenting-complaint/loc_538                                                         1
# http://iers.moh.gov.jo/api/non_reporting/reg_11/22/0/None                                                                1
# http://iers.moh.gov.jo/api/query_category/locations:region/cd_tab/2017-01-01T01:00:00.000Z/2017-09-21T00:00:00.000Z      1
# http://iers.moh.gov.jo/api/aggregate_category/pc/51/2017/tot_1                                                           1
# http://demo.emro.info/robots.txt/                                                                                        1
# http://iers.moh.gov.jo/api/non_reporting/reg_11/12/0/None                                                                1
# http://iers.moh.gov.jo/api/aggregate_category/age/3/2017/tot_1                                                           1
# http://iers.moh.gov.jo/api/aggregate_category/gender/4/2017/prc_2                                                        1
# http://iers.moh.gov.jo/api/aggregate_category/Chapter/570/2017/tot_1                                                     1
# http://iers.moh.gov.jo/en/reports/ebs/443/2017-09-19T00:00:00.000Z/2017-01-01T01:00:00.000Z/                             1
# http://jordan.emro.info/api/aggregate_category/gender/3/2017/prc_2                                                       1
# http://dev.jordan.aws.emro.info/api/key_indicators                                                                       1
# http://review.aws.emro.info/api/variables/alert                                                                          1
# http://iers.moh.gov.jo/api/query_variable/cmd_4/locations:region/2017-01-01T01:00:00.000Z/2017-09-21T00:00:00.000Z       1
# http://iers.moh.gov.jo/api/aggregate_category/visit/628/2017                                                             1
# http://iers.moh.gov.jo/api/aggregate_category/Chapter/12/2017/tot_1                                                      1
# Name: base_url, Length: 1045, dtype: int64

# %%
data["request_time"].max(), data["request_time"].mean()
# Out:
# (40.610305309295654, 0.66513522626156985)

# %%
data.groupby("path").agg({"request_time": ["max", "min", "mean", "std", "count"]
                         })["request_time"].sort_values(by ="mean", ascending=False)
# Out:
#                                                           max        min  \
# path
# /aggregate_category/visit/5/2017                    40.610305  40.610305
# /en/reports/non_communicable_diseases_return_vi...  20.046369  20.046369
# /aggregate_category/pc/5/2017/tot_1                 20.020204  20.020204
# /aggregate_category/Chapter/5/2017/tot_1            20.008009  20.008009
# /en/reports/non_communicable_diseases_new_visit...  17.329325  17.329325
# /en/reports/non_communicable_diseases_return_vi...  16.380693  15.012480
# /reports/ncd_report_return_visits/1/2017-08-31T...  15.764689  14.939328
# /aggregate_category/visit/6/2017                    29.339819   0.807180
# /completeness/reg_11/37/6/1/4,5                     21.474913   9.520266
# /query_category/cd_tab/locations:region/2017-01...  12.769280  12.769280
# /en/reports/non_communicable_diseases_new_visit...  12.611934  12.611934
# /reports/ncd_report_new_visits/7/2017-08-31T00:...  12.538353  12.538353
# /aggregate_category/visit/1/2017                    38.690952   0.008497
# /completeness/reg_11/4/6/1/4,5                       9.731592   8.443622
# /reports/email/cd_public_health/1/                   8.992457   8.992457
# /en/reports/non_communicable_diseases_new_visit...   8.901203   8.799965
# /en/reports/ncd_public_health~7~2017-08-31T00:0...   8.318677   8.318677
# /completeness/reg_11/39/6/1/4,5                     15.218598   0.751002
# /en/reports/ncd_public_health~1~2017-08-31T00:0...   7.698483   7.698483
# /non_reporting/reg_11/37/0/None                      6.331856   6.331856
# /en/reports/cd_public_health~4~2017-09-15T00:00...   6.495195   6.075746
# /reports/email/test_cd_public_health/1/              6.221337   5.993335
# /completeness/reg_11/1/6/1/4,5                       8.521269   2.878238
# /reports/email/test_non_communicable_diseases_n...   5.460785   4.714360
# /reports/email/test_non_communicable_diseases_r...   5.117106   4.993316
# /completeness/reg_6/1/4/1/4,5                        5.820068   2.570088
# /completeness/reg_6/1/4/1/4,5/reg_10                 5.356804   2.602436
# /completeness/reg_11/14/6/1/4,5                      4.525234   4.498144
# /query_variable/vis_1/locations:clinic               4.444957   4.444957
# /en/reports/non_communicable_diseases_new_visit...   5.531117   3.598669
# ...                                                       ...        ...
# /en/technical/alerts/loc_32                          0.001910   0.001784
# /en/technical/cd-completeness/loc_538                0.001818   0.001818
# /en/technical/cd-completeness/loc_526                0.001773   0.001773
# /en/reports/pip/1/2017-09-17T00:00:00.000Z/2016...   0.001493   0.001493
# /en                                                  0.055056   0.000875
# /en/reports/pip/1/2017-09-17T00:00:00.000Z/2016...   0.001418   0.001418
# /en/reports/cd_public_health/4/2017-09-15T00:00...   0.001390   0.001269
# /en/reports/non_communicable_diseases_new_visit...   0.001227   0.001227
# /epi_week                                            0.019459   0.000804
# /en/reports/cd_public_health                         0.001313   0.001103
# /en/reports/ncd_public_health/7/2017-08-31T00:0...   0.001173   0.001173
# /en/reports/cd_public_health/1/2017-08-31T00:00...   0.001163   0.001163
# /en/logout                                           0.002141   0.000994
# /en/reports/non_communicable_diseases_new_visit...   0.001197   0.001097
# /en/reports/public_health                            0.001151   0.001151
# /en/reports/communicable_diseases                    0.001299   0.001060
# /en/reports/ncd_public_health/1/2017-08-31T00:0...   0.001185   0.001091
# /en/reports/non_communicable_diseases_return_vi...   0.001200   0.001075
# /en/reports/communicable_diseases/443/2017-09-1...   0.001125   0.001125
# /en/reports/cd_public_health/1/2017-09-15T00:00...   0.001109   0.001109
# /xmlrpc.php                                          0.001106   0.001106
# /en/reports/cd_public_health/490/2017-09-15T00:...   0.001085   0.001085
# /en/reports/ebs/443/2017-09-19T00:00:00.000Z/20...   0.001080   0.001080
# /en/reports/non_communicable_diseases_new_visits     0.001081   0.001073
# /en/reports/non_communicable_diseases_return_vi...   0.001073   0.001073
# /en/reports/cd_public_health/443/2017-08-31T00:...   0.001069   0.001069
# /en/reports/ncd_public_health                        0.001063   0.001063
# /reccords/ale_1                                      0.001058   0.001058
# /en/reports/cd_public_health/6/2017-09-15T00:00...   0.001044   0.001044
# /wp-login.php                                        0.001055   0.001002
#
#                                                          mean        std  \
# path
# /aggregate_category/visit/5/2017                    40.610305        NaN
# /en/reports/non_communicable_diseases_return_vi...  20.046369        NaN
# /aggregate_category/pc/5/2017/tot_1                 20.020204        NaN
# /aggregate_category/Chapter/5/2017/tot_1            20.008009        NaN
# /en/reports/non_communicable_diseases_new_visit...  17.329325        NaN
# /en/reports/non_communicable_diseases_return_vi...  15.652493   0.688356
# /reports/ncd_report_return_visits/1/2017-08-31T...  15.383811   0.416341
# /aggregate_category/visit/6/2017                    15.073500  20.175622
# /completeness/reg_11/37/6/1/4,5                     14.767030   5.086038
# /query_category/cd_tab/locations:region/2017-01...  12.769280        NaN
# /en/reports/non_communicable_diseases_new_visit...  12.611934        NaN
# /reports/ncd_report_new_visits/7/2017-08-31T00:...  12.538353        NaN
# /aggregate_category/visit/1/2017                     9.226522   9.605665
# /completeness/reg_11/4/6/1/4,5                       9.087607   0.910732
# /reports/email/cd_public_health/1/                   8.992457        NaN
# /en/reports/non_communicable_diseases_new_visit...   8.850584   0.071586
# /en/reports/ncd_public_health~7~2017-08-31T00:0...   8.318677        NaN
# /completeness/reg_11/39/6/1/4,5                      7.991394   8.296386
# /en/reports/ncd_public_health~1~2017-08-31T00:0...   7.698483        NaN
# /non_reporting/reg_11/37/0/None                      6.331856        NaN
# /en/reports/cd_public_health~4~2017-09-15T00:00...   6.285470   0.296595
# /reports/email/test_cd_public_health/1/              6.107336   0.161221
# /completeness/reg_11/1/6/1/4,5                       5.486288   1.613174
# /reports/email/test_non_communicable_diseases_n...   5.087573   0.527802
# /reports/email/test_non_communicable_diseases_r...   5.055211   0.087532
# /completeness/reg_6/1/4/1/4,5                        4.697692   1.139654
# /completeness/reg_6/1/4/1/4,5/reg_10                 4.554285   1.069856
# /completeness/reg_11/14/6/1/4,5                      4.511689   0.019156
# /query_variable/vis_1/locations:clinic               4.444957        NaN
# /en/reports/non_communicable_diseases_new_visit...   4.368435   0.841799
# ...                                                       ...        ...
# /en/technical/alerts/loc_32                          0.001847   0.000089
# /en/technical/cd-completeness/loc_538                0.001818        NaN
# /en/technical/cd-completeness/loc_526                0.001773        NaN
# /en/reports/pip/1/2017-09-17T00:00:00.000Z/2016...   0.001493        NaN
# /en                                                  0.001437   0.003452
# /en/reports/pip/1/2017-09-17T00:00:00.000Z/2016...   0.001418        NaN
# /en/reports/cd_public_health/4/2017-09-15T00:00...   0.001329   0.000085
# /en/reports/non_communicable_diseases_new_visit...   0.001227        NaN
# /epi_week                                            0.001211   0.001397
# /en/reports/cd_public_health                         0.001190   0.000110
# /en/reports/ncd_public_health/7/2017-08-31T00:0...   0.001173        NaN
# /en/reports/cd_public_health/1/2017-08-31T00:00...   0.001163        NaN
# /en/logout                                           0.001162   0.000303
# /en/reports/non_communicable_diseases_new_visit...   0.001155   0.000050
# /en/reports/public_health                            0.001151        NaN
# /en/reports/communicable_diseases                    0.001148   0.000131
# /en/reports/ncd_public_health/1/2017-08-31T00:0...   0.001144   0.000048
# /en/reports/non_communicable_diseases_return_vi...   0.001134   0.000063
# /en/reports/communicable_diseases/443/2017-09-1...   0.001125        NaN
# /en/reports/cd_public_health/1/2017-09-15T00:00...   0.001109        NaN
# /xmlrpc.php                                          0.001106        NaN
# /en/reports/cd_public_health/490/2017-09-15T00:...   0.001085        NaN
# /en/reports/ebs/443/2017-09-19T00:00:00.000Z/20...   0.001080        NaN
# /en/reports/non_communicable_diseases_new_visits     0.001077   0.000005
# /en/reports/non_communicable_diseases_return_vi...   0.001073        NaN
# /en/reports/cd_public_health/443/2017-08-31T00:...   0.001069        NaN
# /en/reports/ncd_public_health                        0.001063        NaN
# /reccords/ale_1                                      0.001058        NaN
# /en/reports/cd_public_health/6/2017-09-15T00:00...   0.001044        NaN
# /wp-login.php                                        0.001022   0.000029
#
#                                                     count
# path
# /aggregate_category/visit/5/2017                        1
# /en/reports/non_communicable_diseases_return_vi...      1
# /aggregate_category/pc/5/2017/tot_1                     1
# /aggregate_category/Chapter/5/2017/tot_1                1
# /en/reports/non_communicable_diseases_new_visit...      1
# /en/reports/non_communicable_diseases_return_vi...      3
# /reports/ncd_report_return_visits/1/2017-08-31T...      3
# /aggregate_category/visit/6/2017                        2
# /completeness/reg_11/37/6/1/4,5                         4
# /query_category/cd_tab/locations:region/2017-01...      1
# /en/reports/non_communicable_diseases_new_visit...      1
# /reports/ncd_report_new_visits/7/2017-08-31T00:...      1
# /aggregate_category/visit/1/2017                       21
# /completeness/reg_11/4/6/1/4,5                          2
# /reports/email/cd_public_health/1/                      1
# /en/reports/non_communicable_diseases_new_visit...      2
# /en/reports/ncd_public_health~7~2017-08-31T00:0...      1
# /completeness/reg_11/39/6/1/4,5                         4
# /en/reports/ncd_public_health~1~2017-08-31T00:0...      1
# /non_reporting/reg_11/37/0/None                         1
# /en/reports/cd_public_health~4~2017-09-15T00:00...      2
# /reports/email/test_cd_public_health/1/                 2
# /completeness/reg_11/1/6/1/4,5                         66
# /reports/email/test_non_communicable_diseases_n...      2
# /reports/email/test_non_communicable_diseases_r...      2
# /completeness/reg_6/1/4/1/4,5                           9
# /completeness/reg_6/1/4/1/4,5/reg_10                    9
# /completeness/reg_11/14/6/1/4,5                         2
# /query_variable/vis_1/locations:clinic                  1
# /en/reports/non_communicable_diseases_new_visit...      4
# ...                                                   ...
# /en/technical/alerts/loc_32                             2
# /en/technical/cd-completeness/loc_538                   1
# /en/technical/cd-completeness/loc_526                   1
# /en/reports/pip/1/2017-09-17T00:00:00.000Z/2016...      1
# /en                                                   754
# /en/reports/pip/1/2017-09-17T00:00:00.000Z/2016...      1
# /en/reports/cd_public_health/4/2017-09-15T00:00...      2
# /en/reports/non_communicable_diseases_new_visit...      1
# /epi_week                                             183
# /en/reports/cd_public_health                            3
# /en/reports/ncd_public_health/7/2017-08-31T00:0...      1
# /en/reports/cd_public_health/1/2017-08-31T00:00...      1
# /en/logout                                             13
# /en/reports/non_communicable_diseases_new_visit...      4
# /en/reports/public_health                               1
# /en/reports/communicable_diseases                       3
# /en/reports/ncd_public_health/1/2017-08-31T00:0...      3
# /en/reports/non_communicable_diseases_return_vi...      3
# /en/reports/communicable_diseases/443/2017-09-1...      1
# /en/reports/cd_public_health/1/2017-09-15T00:00...      1
# /xmlrpc.php                                             1
# /en/reports/cd_public_health/490/2017-09-15T00:...      1
# /en/reports/ebs/443/2017-09-19T00:00:00.000Z/20...      1
# /en/reports/non_communicable_diseases_new_visits        2
# /en/reports/non_communicable_diseases_return_vi...      1
# /en/reports/cd_public_health/443/2017-08-31T00:...      1
# /en/reports/ncd_public_health                           1
# /reccords/ale_1                                         1
# /en/reports/cd_public_health/6/2017-09-15T00:00...      1
# /wp-login.php                                           3
#
# [768 rows x 5 columns]
