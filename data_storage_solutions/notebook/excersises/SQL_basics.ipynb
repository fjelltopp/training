# %% [markdown]
# # SQL Basics

# %% [markdown]
# Import the required Python packages:

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from psycopg2 import ProgrammingError

# %% [markdown]
# To connect to the local database we set up for the Meerkat development environment, we need to run some additional Python commands:

# %%
url = 'postgresql+psycopg2://postgres:postgres@localhost/meerkat_db'
engine = create_engine(url)
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# ## Exercise 1: Basic SQL queries
#
# In this exercise, we write standard SQL queries. Since PostgreSQL data can't be edited by simply opening a file with a text editor, we'll have to resort to the Python client.
#
# For example, this query fetches the name of the location with ID 1

# %%
sql_query = \
"SELECT NAME FROM LOCATIONS WHERE ID = 1;"

session.commit() # These commit lines make sure the session is in its default state even if something goes wrong
result = session.execute(sql_query)
session.commit()

for r in result:
    print(r)
# Out:
# ('Jordan',)

# %% [markdown]
# ### a)
# The "locations" table has a field called parent_location, which refers to the larger region the location is in.
#
# Edit the below query to find the ids and names of locations that have location 1 as their parent_location

# %%
sql_query = \
"SELECT ID, NAME FROM LOCATIONS;"

session.commit() # These commit lines make sure the session is in its default state even if something goes wrong
result = session.execute(sql_query)
session.commit()
for r in result:
    print(r)
# Out:
# (56, 'Al-Rousifeh Al-Shamali')
# (46, 'Shbeeb')
# (12, 'Petra')
# (50, 'Isskan Al-Amir Talal')
# (583, "Al-Batrawi (Hai Ma'asoum)")
# (52, 'Al-Sukhna')
# (28, 'Rweished D')
# (29, 'Berm')
# (31, 'South Aghwar D')
# (585, 'Al-Naqab')
# (39, 'Petra D')
# (32, 'Zarqa D')
# (70, 'Al-Safawi')
# (36, 'Ajloun D')
# (73, 'Al-Turra Al-Janoubi')
# (55, 'in stock')
# (57, 'Al-Khalidiah')
# (58, "Bal'ama")
# (72, 'Al-Ramtha Al-Gharbi')
# (582, 'Al-Tatweer Al-Hadari')
# (2, 'Ajloun')
# (13, 'Ramtha')
# (71, 'Missing')
# (10, 'Madaba')
# (3, 'Amman')
# (63, "Al-Za'tari")
# (42, 'Wadi Al-Hajar')
# (75, 'Kufur Youba')
# (45, 'Jabal Al-Amir Faisal')
# (38, 'Madaba D')
# (26, 'Mafraq D')
# (64, 'Khaled Bin Al-Walid')
# (16, 'Amman D')
# (11, 'Mafraq')
# (48, 'Jabal Tareq')
# (23, 'Koura D')
# (49, 'Hai Al-Ameer Mohammad')
# (61, 'Sama Al-Sarhaan')
# (62, 'Rihab')
# (59, 'Al-Mansourah')
# (41, 'Al-Dleil')
# (34, "Ma'an D")
# (53, 'Abu-Al-Zeighan')
# (19, 'South Shouneh D')
# (21, 'Irbid D')
# (30, 'Karak D')
# (60, 'Al-Mafraq Al-Shamel')
# (5, 'Balqa')
# (7, 'Jarash')
# (43, 'Hai Al-Rasheed')
# (8, 'Karak')
# (44, 'Bereen')
# (9, "Ma'an")
# (33, 'Tafeileh D')
# (68, 'Um Al-Qutein')
# (65, "Al-Ba'ej")
# (67, 'Al-Badiah Al-Shamali')
# (69, 'Deir Al-kahf')
# (20, 'Deir Alla D')
# (14, 'Tafeileh')
# (6, 'Irbid')
# (51, 'Al-Hashimieh')
# (35, 'Jarash D')
# (18, 'Balqa D')
# (22, 'Bani Kenana D')
# (76, 'Dahiyat Al-Hussein')
# (80, 'Malka')
# (83, 'Al-Razi')
# (90, 'Al-Zarka Al-Jadidah')
# (88, 'Al-Turra Al-Shamali')
# (103, 'Al-Amira Basma')
# (78, 'Al-Ramtha Al-Shamel')
# (117, 'Samar')
# (130, 'Al-Hadadah')
# (132, 'Al-Kfeir')
# (154, 'Al-Weibdeh Al-Sharqi')
# (156, 'Amman Al-Shamel')
# (137, 'Al-Basheer Hospital')
# (139, 'Al-Bassa')
# (143, 'Al-Marrekh')
# (144, 'Al-Muraqab')
# (146, 'Al-Nathif')
# (148, 'Al-Qoussour (Al-Hashimi Al-Janoubi)')
# (149, 'Al-Rabwah (Hamlan)')
# (150, 'Al-Rawdah')
# (151, 'Al-Taj')
# (152, 'Al-Tatweer Al-Hadari(Marka)')
# (186, 'Eskan Abu-Nsseir')
# (187, 'Husban')
# (188, 'Istishariah Clinic')
# (189, 'IT Focal')
# (198, 'Dirar Ibn Al-Azwar')
# (199, 'Wadi Al-Akrad')
# (200, 'Al-Rumman')
# (201, 'Tal Almantah')
# (207, 'Allan')
# (208, 'Eira')
# (209, 'Salhoub')
# (110, 'Al-Jafer')
# (197, 'Iskan Al-Maghareeb wa Um-Al-Zaytoon')
# (205, 'Al-Salalem')
# (112, 'Ein Al-Baidah')
# (104, 'Kufor Awan')
# (86, "Al-Na'imeh")
# (138, 'with ICRC')
# (124, 'Al-Salt')
# (128, 'Yarqa')
# (105, 'Yarmouk Hospital')
# (114, 'Al-Mansourah')
# (93, 'Al-Eiss')
# (115, 'Arhab')
# (107, 'Al-Husseiniya')
# (134, 'Al-Reesha')
# (77, "Deir Abi Se'eid")
# (79, "Bait Ra'ass")
# (81, 'Kraimeh')
# (584, 'Hai Al Jundi')
# (85, 'Al-Tatweer Al-Hadari')
# (87, "Samou'e")
# (89, 'Al-Ramtha Main')
# (95, 'Al Mwagar 2')
# (96, 'Abu Ayoub Al-Ansary (Al-Hilal)')
# (97, 'Al Mwagar 1')
# (98, 'Abu Sous\n')
# (99, 'Abu Syah')
# (100, 'Al -Istiqlal')
# (101, "Al-A'al")
# (102, 'Al-Adassieh')
# (74, 'Al-Sareeh')
# (108, 'Soumow Al-Amira Rahma Bent Al-Hasan')
# (109, "Ma'an focal")
# (94, 'Bassirah')
# (116, 'Wadi Al-Rayyan')
# (118, 'Hriema')
# (120, 'Sama Al-Rousan')
# (123, 'Al-Awdah (Um-Tineh)')
# (127, 'S.Shouneh Focal')
# (131, 'Al-Jazazah')
# (133, 'Al-Mastaba')
# (140, 'Al-Hashimi Al-Shamali')
# (141, 'Al-Hashimieh')
# (142, 'Al-Manarah')
# (145, 'Al-Nasser')
# (147, 'Al-Nuzha')
# (153, "Al-Thira'a (Hai Nazzal)")
# (129, 'Al-Rawdah')
# (155, 'Al-Zouhour')
# (157, 'Um-Alrassas')
# (158, 'Nuzhat Sahab')
# (159, 'Amman Focal')
# (161, "Daba'a")
# (162, 'Rajm Al-Shami')
# (160, 'Al-Jweideh')
# (163, 'Bader')
# (164, 'Central Laboratory')
# (165, 'Dahiyat Al-Hussein')
# (166, 'Al-Rmail')
# (167, 'Dr Akram Al Saleh')
# (168, 'Dr Bashar Baninaser')
# (169, 'Ereinbeh Al-Gaharbiah')
# (122, 'Zay')
# (91, 'Al-Qatranah')
# (126, 'Al-Fuheiss')
# (111, 'Al-Shobak')
# (113, 'Arweem')
# (82, 'Rahmah Hospital')
# (170, 'Dr Laura Sawalha')
# (171, 'Al-Thahabiah Al-Sharqiah')
# (172, 'Al-Rama')
# (173, 'Dr Nader Sheikhali')
# (174, "Dr. Asa'ad Rahhal")
# (175, 'Dr. Bassam Shadfan')
# (176, 'Dr. Fateen')
# (177, 'Dr. Kariman Zain')
# (178, 'Dr. Khalil Kenani')
# (179, 'Dr. Mohammad Rashdan')
# (180, 'Um-Alamad')
# (181, 'Dr. Nabil Sabri')
# (182, 'Dr. Refqi Mahmoud')
# (183, 'Dr. Sami Sheikh Ali')
# (184, 'Dr. Sultan Qasrawi')
# (185, 'Eman IT Amman\n')
# (586, 'Isskan Al-Amir Hashem')
# (190, 'Jabal Al-Jofeh')
# (192, 'Al-Sleihi')
# (193, 'Al-Twall Al-Janoubi')
# (194, 'Al-Manshieh')
# (227, 'Al-Ramtha Al-Shamali')
# (202, 'Al-Jofah')
# (203, 'Um-Jozah')
# (204, 'Baqan')
# (234, 'Marj Al-Hamam')
# (211, 'Al-Sarou')
# (212, 'Al-Khandag wa Al-Iskan')
# (228, 'Al-shajrah Al-Janoubi')
# (213, 'Al-Rweihah')
# (196, 'Al Hussein Hospital')
# (214, 'Al-Balawneh')
# (223, 'Kom Al-Raf')
# (225, "Abdel Ra'of IT focal")
# (226, 'Ahmad IT focal')
# (195, 'Jabal Amman')
# (332, 'Al-Razi')
# (191, "Ma'adi")
# (229, 'Jamil Totanji Hospital')
# (206, 'Ain Al-Basha')
# (329, 'Al-Msheirfeh')
# (254, 'Ajloun')
# (336, 'Tharghrat Al-Jib')
# (338, "Al-Rafa'yat")
# (340, 'Rasoun')
# (343, 'Al-Hashimiah')
# (345, 'Al-Harsh')
# (347, "Fa'a")
# (349, 'Sahem')
# (325, 'Ay')
# (210, 'Khazma')
# (328, 'Al-Karamah')
# (224, 'factory')
# (327, "Ma'an")
# (216, 'Al-Jawasreh')
# (217, 'Moubess')
# (218, 'Al-Salalem Al-Oulwi')
# (219, 'Bayouda Al-Sharqieh')
# (220, 'Abu-Nsseir')
# (66, 'Gynecoloy & Obstetrics and Children Hospital')
# (222, 'Al-Yazidieh')
# (588, 'Al-Hallabat Al-Sharqy')
# (589, "Ra'ss Munif")
# (221, 'Mahess')
# (390, 'Madaba Al-Sharqy')
# (615, 'Wadi El-Seer')
# (230, "Khasha' Al-Sleiteen")
# (232, 'North Badia Hospital\n')
# (620, 'Safout')
# (621, 'Zbood')
# (622, 'North Aghwar focal')
# (215, 'Al Shouneh Hospital')
# (27, 'North Badia D')
# (587, 'Hai Al-Falah')
# (393, 'Al-Areed')
# (330, 'Al-Qadissiah')
# (331, 'Al-Rashadiah')
# (84, 'Al-Shajrah Al-Shamali')
# (337, 'Al-Dejnieh')
# (24, 'Ramtha D')
# (341, 'Al-Wahadneh')
# (342, "San'ar")
# (346, 'Al-Mazrah')
# (348, 'Hosha')
# (350, 'Hatem')
# (352, "Al-Ma'abar Wadi Alordon")
# (355, 'Amra wa Ameira')
# (356, 'Tafeileh Focal')
# (384, 'Aqraba')
# (385, 'Irbid Focal')
# (359, 'Kharja')
# (401, 'Al-Muagar')
# (361, 'Al-Taibeh Al-Janoubieh')
# (363, 'Sallehiat Al-Abed')
# (364, 'Shafa Badran')
# (366, 'Tabarbour (Tareq)')
# (367, 'Hayyan Rweibed')
# (370, 'Al-Mabroukah')
# (371, 'Koura Focal')
# (375, 'Ghor Al-Haditha')
# (378, 'Al-Hai Al-Janoubi')
# (379, "Not Used - can't find it")
# (241, 'Al-Rweished Hospital')
# (381, 'Barma')
# (382, 'Deir Al-Liyat')
# (392, 'Al-Istiqlal')
# (397, "Al-Mashare'e")
# (386, 'Badee’ah Hospital')
# (399, "Ba'aoun")
# (402, 'Natel')
# (17, 'East Amman D')
# (403, 'Rawdat Al-Amira Basma')
# (405, 'Al-Kom Al-Ahmar')
# (413, 'Al-Areesh')
# (415, 'Dalilah Al-Hamaideh')
# (344, 'Nadrah')
# (368, 'Al Mafraq Governmental Hospital')
# (262, 'Princess Iman Hospital')
# (233, 'Al Nadeem Governmental Hospital')
# (334, "Jamia'at Al-Yarmouk")
# (388, 'Lub')
# (409, 'Rum')
# (362, 'Petra (Wadi Mousa)')
# (373, "Ghor Al-Mazra'a")
# (270, 'Zarqa Governmental Hospital')
# (351, 'Al-Mansourah')
# (353, 'Al-Sheikh Hussein')
# (396, 'Al-Thuneibeh')
# (135, 'Lost')
# (354, 'Ein Bani Hasan')
# (357, 'Sahab')
# (358, 'Al-Qweismeh')
# (333, 'Al-Taibeh')
# (360, "Deir Abi Se'eid")
# (365, 'Sweileh')
# (369, 'Um Al-Sarb')
# (323, 'Princess Salha(Ghor Al-Safi)')
# (377, 'Al-Dafyaneh')
# (380, 'Balila')
# (383, 'Jabbah')
# (387, 'Waqass')
# (391, 'Al-Mreigha')
# (395, 'South Ghour')
# (398, 'Halawa')
# (400, 'Arajan')
# (404, "Um Al-Nia'am  Al awali")
# (406, "Al-Za'tari")
# (412, 'Al-Karak Governmental Hospital SARI Sentinel Site')
# (414, 'Madaba Al-Gharby')
# (416, 'Mukhayam Madaba')
# (420, 'Al-Amyra')
# (423, 'Jarash')
# (424, 'Jarash Focal')
# (429, 'Aydoun Bani Hasan')
# (430, 'Al-Mafraq')
# (431, 'Um Lolo Correctional Facility')
# (427, "Al-Hamra'a")
# (339, 'Sabha')
# (432, 'Al-Karamah Hospital')
# (433, 'North Badia')
# (435, 'Al-Rafeed')
# (437, 'Al-Farouq')
# (411, "King Abdullah Moa'asses SARI Sentinel Site")
# (445, 'Al-Hemmeh Al-Ordounieh')
# (376, "Fouqou'e")
# (374, 'Al-Rabba')
# (25, 'North Aghwar D')
# (335, 'Raya Hospital')
# (408, 'Al-Aqaba')
# (394, 'Shamal Madaba')
# (389, 'Theeban Al-Shamel')
# (438, 'Al-Tafilah Al-Awali')
# (441, 'Ghrandal')
# (407, 'Al-Baldah Al-Qadeemah')
# (106, 'Sahel Houran')
# (590, 'Jreeba')
# (417, 'Maleeh')
# (418, 'Al-Shounah Al-Shamalieh')
# (419, 'Um-Qais')
# (421, 'Zarqa Focal - lost')
# (422, 'missing')
# (426, 'Jaber Al-Sarhaan')
# (591, 'Um-Al-Sleih')
# (428, 'Manshiat Bani Hasan')
# (434, 'Al-Zbeidiah')
# (436, '863363025649789')
# (119, 'Hakma')
# (440, 'Tafeileh Correctional Facility')
# (592, 'Srout')
# (492, 'factory\n')
# (125, 'Prince Hussein Hospital')
# (300, 'Um Al-Jmal')
# (443, 'Mghayar Al-Sarhaan')
# (493, 'Mothalath Al-Arda')
# (92, 'in stock')
# (442, 'Abu Banna')
# (444, 'Irbid correctional facility')
# (450, 'Kufur Khal')
# (452, 'Nahla')
# (454, 'Sakeb')
# (465, 'Marou')
# (466, 'Al-Mgheier')
# (467, 'Jfein')
# (469, 'Arhaba')
# (470, 'Zahar')
# (471, 'Douqara')
# (478, 'Deir Yousef')
# (479, 'Jahfeieh')
# (480, 'Beit Yafa')
# (481, 'Kufur Rakeb')
# (482, 'Qameem')
# (485, 'Kufur Assad')
# (486, 'Hofa')
# (487, 'Janein Al-Safa')
# (489, 'Tabnah')
# (490, 'Kufor Eibel')
# (491, "Princess Eiman \\ Ma'di Hospital")
# (496, 'Al-Azayda')
# (497, 'Sal')
# (483, 'Al-Husson')
# (500, "Ela'al")
# (501, 'Beit Eidess')
# (468, 'Haneena')
# (488, 'Al-Turkman')
# (439, 'Wad Zaid')
# (235, 'Al-Bweidah')
# (593, 'Al-Alia')
# (410, 'Zarqa Hospital SARI Sentinel Site')
# (477, 'Prince Salma Hospital')
# (594, 'Al-Laban')
# (446, 'Fifa')
# (447, 'Ar-Rukban')
# (448, 'Al-Hadalat')
# (449, 'Ruwayshid Camp')
# (425, 'Jarash Hospital')
# (451, "Mreisse'e")
# (453, 'Qafqafa')
# (455, 'Souf')
# (456, "Ma'een")
# (457, 'Haneena')
# (458, 'Al-Msharfeh')
# (459, 'Al-Twall Al-Shamali')
# (460, 'Armeimeen')
# (461, 'Al-Rama')
# (462, 'Sweimah')
# (463, 'Al-Shounah Al-Janoubiah')
# (464, 'Al-Nahda (Al-Hajar Al-Twall)')
# (472, 'Kreimeh')
# (473, "Al-Hilalia'at")
# (474, 'Al-Faisalieh')
# (475, "Al-Faiha'a")
# (476, 'Madaba Al-Janoubi')
# (494, 'Mafraq Hospital')
# (495, 'Jreineh')
# (514, 'Jijeen')
# (515, 'Bushra')
# (516, "Kufur Al-Ma'a")
# (517, 'Aydoun')
# (595, 'Al-Faisalieh')
# (596, 'Al-Jmaiel')
# (597, 'Khashafiat Al-Dabaybeh')
# (598, 'Al-Zmeileh')
# (599, 'Matar Al-Malika Alia')
# (600, 'Al-Mustanada')
# (601, 'Abu-Alanda')
# (602, 'Al-Taibeh')
# (603, 'Um- Nouwara')
# (604, 'Ohod\n')
# (372, 'Training device\n')
# (605, 'Um Al-Qutain')
# (612, 'Thahrat Al-Ramlah')
# (498, 'Jdeita')
# (502, 'Zoubia')
# (503, 'Zamal')
# (504, 'Kufur Jayez')
# (505, 'Al-Barha')
# (506, "Deir Al-Sa'anah")
# (507, 'Al-Kharaj')
# (508, 'Al-Mazar')
# (509, 'Samma')
# (510, 'Habka')
# (511, 'Al-Ashrafiah')
# (512, 'Hour')
# (513, 'Soum')
# (276, 'Al-Qweirah')
# (539, 'Al-Abdaliah')
# (566, 'Al-Samakiah')
# (567, 'Wadi Al-Karak')
# (568, 'Soul')
# (569, 'Al-Thnayah')
# (570, 'Al-Husseiniya')
# (571, "Al-Jada'a")
# (573, 'Al-Shahaibeh')
# (574, 'Bteir')
# (575, '??\n')
# (613, "Wafa' IT focal")
# (614, 'Sad Al-Sultani')
# (4, 'Aqaba')
# (47, 'Hai Al-Ameer Abdullah')
# (576, 'Dr. Khalid Bahti')
# (577, 'Al-Kamsha')
# (578, 'Al-Alouk')
# (616, 'Jaber AlAnsari\n')
# (617, 'NoorDein IT Tafeileh\n')
# (618, 'Tafeileh Shamel')
# (581, 'Khadem AlHarameen\n')
# (272, 'Prince Faisal Hospital')
# (1, 'Jordan')
# (15, 'Zarqa')
# (606, 'Um Hussein')
# (607, 'Um-Albasateen')
# (608, 'Abu Hulailifah')
# (609, 'Al-Yadoda')
# (484, 'Ibn Seena')
# (610, 'Asem IT Focal')
# (499, 'Houarah')
# (611, 'Riyadi\n')
# (518, 'Katm')
# (519, 'Al-Barha')
# (247, 'Princess Basma Hospital')
# (520, 'Anbah')
# (521, "Samad wa Al-Za'tarah")
# (522, "Fo'ara")
# (523, 'Al-Zahrawi')
# (524, 'Al-Twaal')
# (525, 'Al-Thahabiah Al-Gharbiah')
# (531, 'Al-Isteklal')
# (532, 'Al-Sharah')
# (526, 'Al-Naqirah')
# (533, 'Muthalath Al-Shobak')
# (527, 'Um-Qasseer / Al-Maqablein')
# (534, 'Al-Madawara')
# (535, 'Al-Manshiah')
# (536, 'Al-Farthakh')
# (528, "Al-Mqar'eieh")
# (529, "Ma'an Al-Garbi")
# (530, 'Eil')
# (537, 'Athruh')
# (538, 'Al-Hashimiah')
# (540, 'Dalagha')
# (541, 'Petra IT focal??')
# (542, 'Manshiat Abu Hammour')
# (543, 'Adar')
# (544, 'Al-Rajef')
# (311, 'Al-Karak Governmental Hospital')
# (283, 'Queen Rania Hospital')
# (545, 'Al-Marj')
# (546, 'Al-Taibeh')
# (547, 'Mrawed')
# (548, 'Al-Jadidah')
# (549, 'Damnah')
# (550, 'Rakeen')
# (551, 'Al-Iraq')
# (552, 'Al-Qsser')
# (553, 'Joza')
# (554, 'Al-Yarout')
# (555, "Mu'aab")
# (556, "That Ra'ass")
# (557, 'Kuthraba')
# (559, 'Al-Adnaniah')
# (560, 'Sarfa')
# (561, 'Majra')
# (562, "Muhee'")
# (236, 'Amrawa')
# (237, 'Ramtha Focal')
# (307, 'Anjara')
# (289, 'Princess Salma Hospital')
# (238, 'Ramtha Public Hospital')
# (40, 'foreigner')
# (243, 'Riyadi')
# (245, 'Marka airport')
# (246, 'Abdar')
# (250, 'Marka Al-Shamel')
# (253, 'Ein Jana')
# (255, 'Safa Al-Jadeed (Al-Jabal Al-Akhdar)')
# (257, 'Rajeb')
# (259, 'Awsarah')
# (263, 'Fuhais Hospital')
# (278, 'Aqaba focal')
# (280, 'Hibrass')
# (285, 'Roudet Al-Amir Al-Rasheed')
# (286, 'Madaba Focal')
# (287, 'East Amman focal')
# (291, 'Al-Msheirfeh Al-Shamel')
# (292, 'in stock')
# (320, 'Ayma')
# (294, 'Yabla')
# (296, 'Isskan Al-Hashimieh')
# (273, 'Al-Azraq Al-Shamel')
# (298, 'Al-Beshrieh')
# (305, 'Al Iman Al Hokomi Hospital')
# (301, 'Mafraq Focal')
# (309, 'Al-Ameer Hashem')
# (310, 'Swaga Correctional Facility')
# (312, 'Prince Hamza Hospital SARI Sentinel Site')
# (313, 'Qasr Al-adel')
# (319, 'Deir Alla Focal')
# (322, 'Al-Hassa')
# (266, 'Al-Qadissiah')
# (315, 'Al-Deesah')
# (265, 'Al-Tafilah Al-Shamel')
# (244, 'Wadi El-Hoor')
# (242, 'Al-Sbeihi')
# (240, 'Hai Al-Hussein')
# (267, 'Al-Jarf')
# (324, "Al-Ma'amourah")
# (304, 'Al-Karak')
# (275, 'Al-Shameya')
# (277, 'Al-Amira Basma')
# (564, 'Al-Ghweir')
# (558, "Mou'ta")
# (563, 'Ghor AL-Safi Hospital')
# (565, "Emre'e")
# (572, 'Al-Hewaya')
# (37, 'Aqaba D')
# (579, 'Al-Oumari')
# (580, 'Um Rommana')
# (54, 'Al-Zawahreh')
# (231, 'unrwa')
# (239, 'Al-Mkeifteh')
# (121, "Al-Bqei'e")
# (248, 'Al-Mkheibeah Al-Tahta')
# (256, 'Abeen')
# (260, 'Ein Albostan')
# (261, 'Ajloun Focal')
# (258, 'Sakhra')
# (252, "Na'our")
# (268, 'National Addiction Center')
# (295, 'Koufor Soum')
# (279, 'Abu Seedo')
# (281, 'Al-Manshiah')
# (282, 'Mua’ath Ben Jabal Hospital')
# (297, 'Mafraq Focal')
# (288, 'Al-Jeeza')
# (290, 'Awajan')
# (271, 'Prince Hamza Quarter')
# (293, 'Hartha')
# (269, 'Prince Hamza Hospital')
# (318, 'Balqa Focal')
# (302, 'Talal')
# (251, 'Khreibat Al-Souq')
# (284, "Ma'an Hospital")
# (308, 'Eshtafina')
# (306, 'Al-Amir Hasan (Kufranjah)')
# (326, 'Al-Mazar Al-Janoubi')
# (299, 'Al-Ashrafiah')
# (274, 'Al-Khazzan')
# (303, 'Ghoor Al-Safi Hospital')
# (264, 'Deir Alla')
# (249, 'Abi Obidah Hospital')
# (316, 'Qreiqrah')
# (321, 'Sanfahah')
# (314, 'Hai Al-Karamah')
# (317, 'Rahma')
# (619, '')
# (136, 'Private')

# %% [markdown]
# ### b)
# The table "data" has tuples with pre-calculated variables. The Abacus module calculates these from the ODK data sent by the tablets. Most of the reports query data from this table.
#
# Refer to the SQL reference manual and tutorials to edit the query below to calculate the number of entries with type "case" and date after 2016/07/01.

# %%
sql_query = \
"" 
# Write your own SQL query
# HINT 1: To give more than one filter option, check w3schools section SQL And & Or
# HINT 2: To aggregate several rows to e.g. sums or counts, check w3schools section SQL Functions

session.commit() # These commit lines make sure the session is in its default state even if something goes wrong
result = session.execute(sql_query)
session.commit()
for r in result:
    print(r.id, r.name)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     468     def do_execute(self, cursor, statement, parameters, context=None):
# --> 469         cursor.execute(statement, parameters)
#     470
#
# ProgrammingError: can't execute an empty query
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-39-62174cd87247> in <module>()
#       2
#       3 session.commit() # These commit lines make sure the session is in its default state even if something goes wrong
# ----> 4 result = session.execute(sql_query)
#       5 session.commit()
#       6 for r in result:
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/orm/session.py in execute(self, clause, params, mapper, bind, **kw)
#    1105
#    1106         return self._connection_for_bind(
# -> 1107             bind, close_with_result=True).execute(clause, params or {})
#    1108
#    1109     def scalar(self, clause, params=None, mapper=None, bind=None, **kw):
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     943             raise exc.ObjectNotExecutableError(object)
#     944         else:
# --> 945             return meth(self, multiparams, params)
#     946
#     947     def _execute_function(self, func, multiparams, params):
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     261     def _execute_on_connection(self, connection, multiparams, params):
#     262         if self.supports_execution:
# --> 263             return connection._execute_clauseelement(self, multiparams, params)
#     264         else:
#     265             raise exc.ObjectNotExecutableError(self)
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1051             compiled_sql,
#    1052             distilled_params,
# -> 1053             compiled_sql, distilled_params
#    1054         )
#    1055         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1187                 parameters,
#    1188                 cursor,
# -> 1189                 context)
#    1190
#    1191         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1391                 util.raise_from_cause(
#    1392                     sqlalchemy_exception,
# -> 1393                     exc_info
#    1394                 )
#    1395             else:
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     200     exc_type, exc_value, exc_tb = exc_info
#     201     cause = exc_value if exc_value is not exception else None
# --> 202     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     203
#     204 if py3k:
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     183             value.__cause__ = cause
#     184         if value.__traceback__ is not tb:
# --> 185             raise value.with_traceback(tb)
#     186         raise value
#     187
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1180                         statement,
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#    1184             self._handle_dbapi_exception(
#
# /opt/conda/lib/python3.5/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     467
#     468     def do_execute(self, cursor, statement, parameters, context=None):
# --> 469         cursor.execute(statement, parameters)
#     470
#     471     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.ProgrammingError) can't execute an empty query

# %% [markdown]
# ## Exercise 2: Querying JSON objects in PostgreSQL
#
# Standard SQL does not include JSON objects that can be queried. PostgreSQL includes this feature as an extension.
#
# The main data table "data" has several JSON columns. The column "variables" is a JSON column that has pre-calculated variables as key-value pairs. These variables are used to filter and sum data in the frontend reports.
#
# This sample query fetches the rows from the table data that have the following key-value pairs in the "variables" JSON column:
#  - gen_1 : 1
#  - nat_1 : 1

# %%
sql_query = \
"SELECT ID, CLINIC, DATE FROM DATA WHERE VARIABLES->>'gen_1' = '1' AND VARIABLES->>'nat_1' = '1' LIMIT 10" 
# ->> is used to access a key-value pair in a JSON column. The value will be returned as character string


session.commit()
result = session.execute(sql_query)
session.commit()
for r in result:
    print(r.id, r.clinic, r.date)
# Out:
# 1 60 2015-09-05 00:00:00
# 6 322 2015-06-21 00:00:00
# 7 414 2015-10-24 00:00:00
# 11 416 2016-11-05 00:00:00
# 600 600 2016-12-19 00:00:00
# 15 325 2016-12-06 00:00:00
# 18 309 2016-11-08 00:00:00
# 61 264 2016-04-23 00:00:00
# 20 228 2017-01-21 00:00:00
# 25 126 2016-10-15 00:00:00

# %% [markdown]
# ### a)
# Write a query that counts the number of rows in the variable table that have date between 2017/02/19 and 2017/02/23 as well as have either variable "nat_1" or "nat_2" as 1.

# %%
sql_query = \
"" 
# Write your SQL query here


session.commit()
result = session.execute(sql_query)
session.commit()
for r in result:
    print(r.id, r.clinic, r.date)

# %% [markdown]
# ### b)
# Write the query above with using the "@>" or "<@" JSON operator. Refer to PostgreSQL documentation for guidelines

# %%
sql_query = \
"" 
# Write your SQL query here

session.commit()
result = session.execute(sql_query)
session.commit()
for r in result:
    print(r.id, r.clinic, r.date)
